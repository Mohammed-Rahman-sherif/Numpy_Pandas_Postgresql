# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\smart\Documents\Datasets\BlackFridaySales\\train.csv", header= 0)

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
#df[['Product_Category_3', 'Product_Category_2']] = df[['Product_Category_3', 'Product_Category_2']].fillna({'Product_Category_3': 0, 'Product_Category_2': 0})

# %%
df['Product_Category_3'] = df['Product_Category_3'].fillna(0)
df['Product_Category_2'] = df['Product_Category_2'].fillna(0)
df['Product_Category_1'] = df['Product_Category_1'].fillna(0)

# %%
df.head(10)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042      F   0-17          10             A
# 1  1000001  P00248942      F   0-17          10             A
# 2  1000001  P00087842      F   0-17          10             A
# 3  1000001  P00085442      F   0-17          10             A
# 4  1000002  P00285442      M    55+          16             C
# 5  1000003  P00193542      M  26-35          15             A
# 6  1000004  P00184942      M  46-50           7             B
# 7  1000004  P00346142      M  46-50           7             B
# 8  1000004   P0097242      M  46-50           7             B
# 9  1000005  P00274942      M  26-35          20             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       550068.000000       550068.000000  550068.000000
# mean             6.735436            3.841941    9263.968713
# std              6.215492            6.250712    5023.065394
# min              0.000000            0.000000      12.000000
# ...

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Stay_In_Current_City_Years'].replace('4+', '4', inplace=True)
df['Age'].replace(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'], ['0', '55', '26', '46', '51', '36', '18'], inplace=True)

# %%
df.tail(20)
# Out:
#         User_ID Product_ID Gender Age  Occupation City_Category  \
# 550048  1006010  P00371644      M  36           0             C
# 550049  1006011  P00375436      M  36          15             C
# 550050  1006012  P00371644      M  36          15             C
# 550051  1006013  P00375436      F  26          20             C
# 550052  1006016  P00375436      M  46           1             B
# 550053  1006017  P00371644      F  36           7             B
# 550054  1006018  P00370293      M  36           1             C
# 550055  1006019  P00372445      M  26           0             A
# 550056  1006022  P00375436      M  26          17             C
# 550057  1006023  P00370853      M  26           0             C
# 550058  1006024  P00372445      M  26          12             A
# 550059  1006025  P00370853      F  26           1             B
# 550060  1006026  P00371644      M  36           6             C
# 550061  1006029  P00372445      F  26           1             C
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       550068.000000       550068.000000  550068.000000
# mean             6.735436            3.841941    9263.968713
# std              6.215492            6.250712    5023.065394
# min              0.000000            0.000000      12.000000
# ...

# %%
df.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
df['Age'] = df['Age'].astype('int')
df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].astype('int')
df['Product_Category_1'] = df['Product_Category_1'].astype('float')

# %%
df.describe()
# Out:
#             User_ID            Age     Occupation  Stay_In_Current_City_Years  \
# count  5.500680e+05  550068.000000  550068.000000               550068.000000
# mean   1.003029e+06      30.381929       8.076707                    1.858418
# std    1.727592e+03      11.866333       6.522660                    1.289443
# min    1.000001e+06       0.000000       0.000000                    0.000000
# 25%    1.001516e+06      26.000000       2.000000                    1.000000
# 50%    1.003077e+06      26.000000       7.000000                    2.000000
# 75%    1.004478e+06      36.000000      14.000000                    3.000000
# max    1.006040e+06      55.000000      20.000000                    4.000000
#
#        Marital_Status  Product_Category_1  Product_Category_2  \
# count   550068.000000       550068.000000       550068.000000
# mean         0.409653            5.404270            6.735436
# std          0.491770            3.936211            6.215492
# ...

# %%
#df.drop_duplicates(subset=['Gender'], keep='first', inplace=True, ignore_index=False)
df.drop_duplicates()
# Out:
#         User_ID Product_ID Gender  Age  Occupation City_Category  \
# 0       1000001  P00069042      F    0          10             A
# 1       1000001  P00248942      F    0          10             A
# 2       1000001  P00087842      F    0          10             A
# 3       1000001  P00085442      F    0          10             A
# 4       1000002  P00285442      M   55          16             C
# ...         ...        ...    ...  ...         ...           ...
# 550063  1006033  P00372445      M   51          13             B
# 550064  1006035  P00375436      F   26           1             C
# 550065  1006036  P00375436      F   26          15             B
# 550066  1006038  P00375436      F   55           1             C
# 550067  1006039  P00371644      F   46           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               0                 3.0
# ...

# %%
df
# Out:
#         User_ID Product_ID Gender  Age  Occupation City_Category  \
# 0       1000001  P00069042      F    0          10             A
# 1       1000001  P00248942      F    0          10             A
# 2       1000001  P00087842      F    0          10             A
# 3       1000001  P00085442      F    0          10             A
# 4       1000002  P00285442      M   55          16             C
# ...         ...        ...    ...  ...         ...           ...
# 550063  1006033  P00372445      M   51          13             B
# 550064  1006035  P00375436      F   26           1             C
# 550065  1006036  P00375436      F   26          15             B
# 550066  1006038  P00375436      F   55           1             C
# 550067  1006039  P00371644      F   46           0             B
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               0                 3.0
# ...

# %%
df.corr()
# Out:
#                              User_ID       Age  Occupation  \
# User_ID                     1.000000  0.037384   -0.023971
# Age                         0.037384  1.000000    0.085365
# Occupation                 -0.023971  0.085365    1.000000
# Stay_In_Current_City_Years -0.030737 -0.004984    0.030005
# Marital_Status              0.020443  0.319883    0.024280
# Product_Category_1          0.003825  0.059798   -0.007618
# Product_Category_2          0.003896  0.019731    0.006712
# Product_Category_3          0.003605 -0.006498    0.012269
# Purchase                    0.004716  0.016296    0.020833
#
#                             Stay_In_Current_City_Years  Marital_Status  \
# User_ID                                      -0.030737        0.020443
# Age                                          -0.004984        0.319883
# Occupation                                    0.030005        0.024280
# Stay_In_Current_City_Years                    1.000000       -0.012819
# ...
